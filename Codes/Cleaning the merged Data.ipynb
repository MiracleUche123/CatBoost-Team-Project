# %%
import pandas as pd

# %%
remittance = pd.read_csv(r"C:\Users\chine\Downloads\New DataSet\merged_data.csv")

# %%
remittance
# Out:
#                       country_name country_code  Year  remittance_received  \
# 0                            Aruba          ABW  1960                  NaN
# 1      Africa Eastern and Southern          AFE  1960                  NaN
# 2                      Afghanistan          AFG  1960                  NaN
# 3       Africa Western and Central          AFW  1960                  NaN
# 4                           Angola          AGO  1960                  NaN
# ...                            ...          ...   ...                  ...
# 16753                       Kosovo          XKX  2022         1.612854e+09
# 16754                  Yemen, Rep.          YEM  2022                  NaN
# 16755                 South Africa          ZAF  2022         8.728556e+08
# 16756                       Zambia          ZMB  2022         2.434860e+08
# 16757                     Zimbabwe          ZWE  2022         2.047406e+09
#
#        remittance_paid        gdp  unemployment_rate
# ...

# %%
# checking for data types
remittance.dtypes
# Out:
# country_name            object
# country_code            object
# Year                     int64
# remittance_received    float64
# remittance_paid        float64
# gdp                    float64
# unemployment_rate      float64
# dtype: object

# %%
# converting the Year column to datetime
remittance['Year'] = pd.to_datetime(remittance['Year'], format="%Y").dt.year

# %%
remittance
# Out:
#                       country_name country_code  Year  remittance_received  \
# 0                            Aruba          ABW  1960                  NaN
# 1      Africa Eastern and Southern          AFE  1960                  NaN
# 2                      Afghanistan          AFG  1960                  NaN
# 3       Africa Western and Central          AFW  1960                  NaN
# 4                           Angola          AGO  1960                  NaN
# ...                            ...          ...   ...                  ...
# 16753                       Kosovo          XKX  2022         1.612854e+09
# 16754                  Yemen, Rep.          YEM  2022                  NaN
# 16755                 South Africa          ZAF  2022         8.728556e+08
# 16756                       Zambia          ZMB  2022         2.434860e+08
# 16757                     Zimbabwe          ZWE  2022         2.047406e+09
#
#        remittance_paid        gdp  unemployment_rate
# ...

# %%
# checking for duplicate
remittance.duplicated().sum()
# Out:
# 0

# %%
# checking for null value
remittance.isna().sum()
# Out:
# country_name              0
# country_code              0
# Year                      0
# remittance_received    7261
# remittance_paid        7692
# gdp                    7927
# unemployment_rate      9246
# dtype: int64

# %%
# checking data shape
remittance.shape
# Out:
# (16758, 7)

# %%
# removing the year that has no data at all which is from 1960 to 1969
remittance = remittance.drop(remittance.index[:2660])
remittance
# Out:
#                       country_name country_code  Year  remittance_received  \
# 2660                         Aruba          ABW  1970                  NaN
# 2661   Africa Eastern and Southern          AFE  1970         2.265999e+07
# 2662                   Afghanistan          AFG  1970                  NaN
# 2663    Africa Western and Central          AFW  1970                  NaN
# 2664                        Angola          AGO  1970                  NaN
# ...                            ...          ...   ...                  ...
# 16753                       Kosovo          XKX  2022         1.612854e+09
# 16754                  Yemen, Rep.          YEM  2022                  NaN
# 16755                 South Africa          ZAF  2022         8.728556e+08
# 16756                       Zambia          ZMB  2022         2.434860e+08
# 16757                     Zimbabwe          ZWE  2022         2.047406e+09
#
#        remittance_paid        gdp  unemployment_rate
# ...

# %%
# rechecking shape to be sure the chnage has been effected
remittance.shape
# Out:
# (14098, 7)

# %%
# Filling null values
remittance.fillna(0, inplace = True)

# %%
#To save to csv
remittance.to_csv(r"C:\Users\chine\Downloads\Cleaned Data\Remittance 1970 - 2022.csv", index = False)
