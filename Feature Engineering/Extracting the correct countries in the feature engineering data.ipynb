# %%
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
# Importing the metadata that does not have continents and subregions only countries
metadata_country =pd.read_csv(r"C:\Users\chine\Downloads\Catboost Project\Cleaned Data\Cleaned Data\MetaData.csv" ,encoding ="latin-1")
metadata_country
# Out:
#      country_name Country Code                      Region  \
# 0           Aruba          ABW   Latin America & Caribbean
# 1     Afghanistan          AFG                  South Asia
# 2          Angola          AGO          Sub-Saharan Africa
# 3         Albania          ALB       Europe & Central Asia
# 4         Andorra          AND       Europe & Central Asia
# ..            ...          ...                         ...
# 212        Kosovo          XKX       Europe & Central Asia
# 213   Yemen, Rep.          YEM  Middle East & North Africa
# 214  South Africa          ZAF          Sub-Saharan Africa
# 215        Zambia          ZMB          Sub-Saharan Africa
# 216      Zimbabwe          ZWE          Sub-Saharan Africa
#
#              IncomeGroup                                       SpecialNotes
# 0            High income                                                NaN
# 1             Low income  The reporting period for national accounts dat...
# ...

# %%
# checking the total number of the countries in metadata
metadata_country['country_name'].nunique()
# Out:
# 217

# %%
remittance= pd.read_csv(r"C:\Users\chine\Downloads\Catboost Project\Cleaned Data\Cleaned Data\merged_with_data.csv")
remittance
# Out:
#        Year country_code country_name       gdp     new_income_group  \
# 0      1970          AFG  Afghanistan  0.000000           Low income
# 1      1971          AFG  Afghanistan  0.000000           Low income
# 2      1972          AFG  Afghanistan  0.000000           Low income
# 3      1973          AFG  Afghanistan  0.000000           Low income
# 4      1974          AFG  Afghanistan  0.000000           Low income
# ...     ...          ...          ...       ...                  ...
# 14093  2018          ZWE     Zimbabwe  4.179939  Lower middle income
# 14094  2019          ZWE     Zimbabwe  6.490458  Lower middle income
# 14095  2020          ZWE     Zimbabwe  8.517271  Lower middle income
# 14096  2021          ZWE     Zimbabwe  6.985948  Lower middle income
# 14097  2022          ZWE     Zimbabwe  9.901347  Lower middle income
#
#                new_region  population  remittance_growth_rate  \
# 0              South Asia  10752971.0                0.000000
# ...

# %%
# checking the total number of the remittance data
remittance['country_name'].nunique()
# Out:
# 266

# %% [markdown]
# There are 217 countries in the metadata  But we have 266  in the remittance data set
# We need to find the countries that are not supposed to be in the remittance data

# %%
# Getting the names of the countries in the remittance datafarme and storing them in a list
remittance_country_list = remittance['country_name'].unique()
remittance_country_list
# Out:
# array(['Afghanistan', 'Africa Eastern and Southern',
#        'Africa Western and Central', 'Albania', 'Algeria',
#        'American Samoa', 'Andorra', 'Angola', 'Antigua and Barbuda',
#        'Arab World', 'Argentina', 'Armenia', 'Aruba', 'Australia',
#        'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain', 'Bangladesh',
#        'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda',
#        'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana',
#        'Brazil', 'British Virgin Islands', 'Brunei Darussalam',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia',
#        'Cameroon', 'Canada', 'Caribbean small states', 'Cayman Islands',
#        'Central African Republic', 'Central Europe and the Baltics',
#        'Chad', 'Channel Islands', 'Chile', 'China', 'Colombia', 'Comoros',
#        'Congo, Dem. Rep.', 'Congo, Rep.', 'Costa Rica', "Cote d'Ivoire",
#        'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czechia', 'Denmark',
# ...

# %%
len(remittance_country_list)
# Out:
# 266

# %%
# Lets get the unique names of countries in metadata  and Create a list to store the  countries 
metadata_country_list = metadata_country['country_name'].unique() 
metadata_country_list
# Out:
# array(['Aruba', 'Afghanistan', 'Angola', 'Albania', 'Andorra',
#        'United Arab Emirates', 'Argentina', 'Armenia', 'American Samoa',
#        'Antigua and Barbuda', 'Australia', 'Austria', 'Azerbaijan',
#        'Burundi', 'Belgium', 'Benin', 'Burkina Faso', 'Bangladesh',
#        'Bulgaria', 'Bahrain', 'Bahamas, The', 'Bosnia and Herzegovina',
#        'Belarus', 'Belize', 'Bermuda', 'Bolivia', 'Brazil', 'Barbados',
#        'Brunei Darussalam', 'Bhutan', 'Botswana',
#        'Central African Republic', 'Canada', 'Switzerland',
#        'Channel Islands', 'Chile', 'China', "Cote d'Ivoire", 'Cameroon',
#        'Congo, Dem. Rep.', 'Congo, Rep.', 'Colombia', 'Comoros',
#        'Cabo Verde', 'Costa Rica', 'Cuba', 'Curacao', 'Cayman Islands',
#        'Cyprus', 'Czechia', 'Germany', 'Djibouti', 'Dominica', 'Denmark',
#        'Dominican Republic', 'Algeria', 'Ecuador', 'Egypt, Arab Rep.',
#        'Eritrea', 'Spain', 'Estonia', 'Ethiopia', 'Finland', 'Fiji',
# ...

# %%
len(metadata_country_list)
# Out:
# 217

# %%
# Lets confirm if the number of coutries we have in our remittance dataset is equal to the number of countries
# we have metadata set
remittance_country_list == metadata_country_list
# Out:
# False

# %%
# a dataframe to extract only the countries in metadata country dataset

realcountries = remittance[remittance['country_name'].isin(metadata_country_list)]
realcountries
# Out:
#        Year country_code country_name       gdp     new_income_group  \
# 0      1970          AFG  Afghanistan  0.000000           Low income
# 1      1971          AFG  Afghanistan  0.000000           Low income
# 2      1972          AFG  Afghanistan  0.000000           Low income
# 3      1973          AFG  Afghanistan  0.000000           Low income
# 4      1974          AFG  Afghanistan  0.000000           Low income
# ...     ...          ...          ...       ...                  ...
# 14093  2018          ZWE     Zimbabwe  4.179939  Lower middle income
# 14094  2019          ZWE     Zimbabwe  6.490458  Lower middle income
# 14095  2020          ZWE     Zimbabwe  8.517271  Lower middle income
# 14096  2021          ZWE     Zimbabwe  6.985948  Lower middle income
# 14097  2022          ZWE     Zimbabwe  9.901347  Lower middle income
#
#                new_region  population  remittance_growth_rate  \
# 0              South Asia  10752971.0                0.000000
# ...

# %%
# checking the total number of the remmitance data
realcountries['country_name'].nunique()
# Out:
# 217

# %%
# Getting the names of the countries that are not metadata country data set
print(set(remittance_country_list) ^ set(metadata_country_list))
# Out:
# {'Middle East & North Africa (IDA & IBRD countries)', 'IBRD only', 'IDA total', 'Europe & Central Asia (excluding high income)', 'Not classified', 'Latin America & Caribbean (excluding high income)', 'Small states', 'East Asia & Pacific (excluding high income)', 'South Asia', 'Caribbean small states', 'Arab World', 'IDA blend', 'East Asia & Pacific', 'World', 'Post-demographic dividend', 'Lower middle income', 'Africa Western and Central', 'Central Europe and the Baltics', 'Middle East & North Africa (excluding high income)', 'Pre-demographic dividend', 'Europe & Central Asia', 'Low & middle income', 'Sub-Saharan Africa (excluding high income)', 'Low income', 'European Union', 'Least developed countries: UN classification', 'Heavily indebted poor countries (HIPC)', 'South Asia (IDA & IBRD)', 'Sub-Saharan Africa (IDA & IBRD countries)', 'Middle East & North Africa', 'Europe & Central Asia (IDA & IBRD countries)', 'Africa Eastern and Southern', 'IDA only', 'Pacific island small states'
# ...

# %%
#Renaming the column names for better understanding
realcountries.rename(columns={'new_income_group': 'income_group', 'new_region': 'region'}, inplace=True)

# %%
realcountries.to_csv(r"C:\Users\chine\Downloads\Catboost Project\Cleaned Data\Remittance 1970 - 2022 -Chinelo.csv", index = False)   #To save to csv
