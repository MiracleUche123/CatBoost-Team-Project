# %%
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
metadata_country =pd.read_csv(r"C:\Users\chine\Downloads\Cleaned Data\MetaData Country.csv" ,encoding ="latin-1")
metadata_country
# Out:
#      country_name Country Code                      Region  \
# 0           Aruba          ABW   Latin America & Caribbean
# 1     Afghanistan          AFG                  South Asia
# 2          Angola          AGO          Sub-Saharan Africa
# 3         Albania          ALB       Europe & Central Asia
# 4         Andorra          AND       Europe & Central Asia
# ..            ...          ...                         ...
# 212        Kosovo          XKX       Europe & Central Asia
# 213   Yemen, Rep.          YEM  Middle East & North Africa
# 214  South Africa          ZAF          Sub-Saharan Africa
# 215        Zambia          ZMB          Sub-Saharan Africa
# 216      Zimbabwe          ZWE          Sub-Saharan Africa
#
#              IncomeGroup                                       SpecialNotes
# 0            High income                                                NaN
# 1             Low income  The reporting period for national accounts dat...
# ...

# %%
# checking the total number of the countries in metadata
metadata_country['country_name'].nunique()
# Out:
# 217

# %%
remittance= pd.read_csv(r"C:\Users\chine\Downloads\Cleaned Data\Remittance 1970 - 2022.csv")
remittance
# Out:
#                       country_name country_code  Year  remittance_received  \
# 0                            Aruba          ABW  1970         0.000000e+00
# 1      Africa Eastern and Southern          AFE  1970         2.265999e+07
# 2                      Afghanistan          AFG  1970         0.000000e+00
# 3       Africa Western and Central          AFW  1970         0.000000e+00
# 4                           Angola          AGO  1970         0.000000e+00
# ...                            ...          ...   ...                  ...
# 14093                       Kosovo          XKX  2022         1.612854e+09
# 14094                  Yemen, Rep.          YEM  2022         0.000000e+00
# 14095                 South Africa          ZAF  2022         8.728556e+08
# 14096                       Zambia          ZMB  2022         2.434860e+08
# 14097                     Zimbabwe          ZWE  2022         2.047406e+09
#
#        remittance_paid        gdp  unemployment_rate
# ...

# %%
# checking the total number of the remittance data
remittance['country_name'].nunique()
# Out:
# 266

# %%
# Lets get the unique names of Countries in metadata country dataset and Create a list to store the  countries 
metadata_country_list = metadata_country['country_name'].unique() 
metadata_country_list
# Out:
# array(['Aruba', 'Afghanistan', 'Angola', 'Albania', 'Andorra',
#        'United Arab Emirates', 'Argentina', 'Armenia', 'American Samoa',
#        'Antigua and Barbuda', 'Australia', 'Austria', 'Azerbaijan',
#        'Burundi', 'Belgium', 'Benin', 'Burkina Faso', 'Bangladesh',
#        'Bulgaria', 'Bahrain', 'Bahamas, The', 'Bosnia and Herzegovina',
#        'Belarus', 'Belize', 'Bermuda', 'Bolivia', 'Brazil', 'Barbados',
#        'Brunei Darussalam', 'Bhutan', 'Botswana',
#        'Central African Republic', 'Canada', 'Switzerland',
#        'Channel Islands', 'Chile', 'China', "Côte d'Ivoire", 'Cameroon',
#        'Congo, Dem. Rep.', 'Congo, Rep.', 'Colombia', 'Comoros',
#        'Cabo Verde', 'Costa Rica', 'Cuba', 'Curaçao', 'Cayman Islands',
#        'Cyprus', 'Czechia', 'Germany', 'Djibouti', 'Dominica', 'Denmark',
#        'Dominican Republic', 'Algeria', 'Ecuador', 'Egypt, Arab Rep.',
#        'Eritrea', 'Spain', 'Estonia', 'Ethiopia', 'Finland', 'Fiji',
# ...

# %%
# a dataframe to get only the names of countries in metadata country dataset

realcountries = remittance[remittance['country_name'].isin(metadata_country_list)]
realcountries
# Out:
#        country_name country_code  Year  remittance_received  remittance_paid  \
# 0             Aruba          ABW  1970         0.000000e+00     0.000000e+00
# 2       Afghanistan          AFG  1970         0.000000e+00     0.000000e+00
# 4            Angola          AGO  1970         0.000000e+00     0.000000e+00
# 5           Albania          ALB  1970         0.000000e+00     0.000000e+00
# 6           Andorra          AND  1970         0.000000e+00     0.000000e+00
# ...             ...          ...   ...                  ...              ...
# 14093        Kosovo          XKX  2022         1.612854e+09     6.071223e+07
# 14094   Yemen, Rep.          YEM  2022         0.000000e+00     0.000000e+00
# 14095  South Africa          ZAF  2022         8.728556e+08     1.011890e+09
# 14096        Zambia          ZMB  2022         2.434860e+08     1.312541e+08
# 14097      Zimbabwe          ZWE  2022         2.047406e+09     0.000000e+00
#
#              gdp  unemployment_rate
# ...

# %%
# checking the total number of the remmitance data
remittance['country_name'].nunique()
# Out:
# 266

# %% [markdown]
# There are 217 countries in the metadata  But we have 266  in the remittance data set
# We need to find the countries that are not supposed to be in the remittance data

# %%
# make a copy of the country data
metadata_country_copy = metadata_country.copy()

# %%
# Getting the names of the countries in the remittance datafarme and storing them in a list
remittance_country_list = remittance['country_name'].unique()
remittance_country_list
# Out:
# array(['Aruba', 'Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina', 'Armenia',
#        'American Samoa', 'Antigua and Barbuda', 'Australia', 'Austria',
#        'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso',
#        'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas, The',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda',
#        'Bolivia', 'Brazil', 'Barbados', 'Brunei Darussalam', 'Bhutan',
#        'Botswana', 'Central African Republic', 'Canada',
#        'Central Europe and the Baltics', 'Switzerland', 'Channel Islands',
#        'Chile', 'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.',
#        'Congo, Rep.', 'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica',
#        'Caribbean small states', 'Cuba', 'Curacao', 'Cayman Islands',
#        'Cyprus', 'Czechia', 'Germany', 'Djibouti', 'Dominica', 'Denmark',
# ...

# %%
# Lets confirm if the number of coutries we have in our remittance dataset is equal to the number of countries
# we have metadata set
remittance_country_list == metadata_country_list
# Out:
# False

# %%
# making a copy of the remittance data this is to enable us delete these countries that are in the remittance 
# dateset but not in the metadata country dataset. 
remittance_copy = remittance.copy()
remittance_copy
# Out:
#                       country_name country_code  Year  remittance_received  \
# 0                            Aruba          ABW  1970         0.000000e+00
# 1      Africa Eastern and Southern          AFE  1970         2.265999e+07
# 2                      Afghanistan          AFG  1970         0.000000e+00
# 3       Africa Western and Central          AFW  1970         0.000000e+00
# 4                           Angola          AGO  1970         0.000000e+00
# ...                            ...          ...   ...                  ...
# 14093                       Kosovo          XKX  2022         1.612854e+09
# 14094                  Yemen, Rep.          YEM  2022         0.000000e+00
# 14095                 South Africa          ZAF  2022         8.728556e+08
# 14096                       Zambia          ZMB  2022         2.434860e+08
# 14097                     Zimbabwe          ZWE  2022         2.047406e+09
#
#        remittance_paid        gdp  unemployment_rate
# ...

# %%
# Getting the names of the countries that are not metadata country data set
print(set(remittance_country_list) ^ set(metadata_country_list))
# Out:
# {'Lower middle income', 'East Asia & Pacific', 'Europe & Central Asia', 'Latin America & the Caribbean (IDA & IBRD countries)', 'Least developed countries: UN classification', 'Caribbean small states', 'Low income', 'South Asia', 'Latin America & Caribbean', 'East Asia & Pacific (IDA & IBRD countries)', 'Europe & Central Asia (excluding high income)', 'North America', 'Fragile and conflict affected situations', 'East Asia & Pacific (excluding high income)', 'OECD members', 'IBRD only', 'Middle income', 'High income', 'IDA total', 'Türkiye', 'Small states', 'Latin America & Caribbean (excluding high income)', 'Late-demographic dividend', 'Africa Eastern and Southern', 'Turkiye', 'IDA only', 'Africa Western and Central', 'Other small states', 'Pre-demographic dividend', 'Sao Tome and Principe', 'Sub-Saharan Africa', 'Sub-Saharan Africa (IDA & IBRD countries)', 'Curaçao', 'Arab World', 'Middle East & North Africa (IDA & IBRD countries)', 'Post-demographic dividend', 'Middle East & North
# ...

# %%
# removing the countries so the number of countries in metadata will be thesame  in the remittance data
indexNames = remittance_copy[(remittance_copy['country_name'] == 'Lower middle income') | 
                                  (remittance_copy['country_name'] == 'East Asia & Pacific') | 
                                 (remittance_copy['country_name'] == 'Europe & Central Asia') | 
                                (remittance_copy['country_name'] == 'Latin America & the Caribbean (IDA & IBRD countries)') | 
                                (remittance_copy['country_name'] == 'Least developed countries: UN classification') |
                                (remittance_copy['country_name'] == 'Caribbean small states') |
                             (remittance_copy['country_name'] == 'Low income') |
                             (remittance_copy['country_name'] == 'South Asia') |
                             (remittance_copy['country_name'] == 'Latin America & Caribbean') |
                             (remittance_copy['country_name'] == 'East Asia & Pacific (IDA & IBRD countries)') |
                             (remittance_copy['country_name'] == 'Europe & Central Asia (excluding high income)') |
                             (remittance_copy['country_name'] == 'North America') |
                             (remittance_copy['country_name'] == 'Fragile and conflict affected situations') |
                             (remittance_copy['country_name'] == 'East Asia & Pacific (excluding high income)') |
                             (remittance_copy['country_name'] == 'OECD members') |
                             (remittance_copy['country_name'] == 'IBRD only') |
                             (remittance_copy['country_name'] == 'Middle income') |
                             (remittance_copy['country_name'] == 'High income') |
                             (remittance_copy['country_name'] == 'IDA total') |
                             (remittance_copy['country_name'] == 'Türkiye') |
                             (remittance_copy['country_name'] == 'Small states') |
                             (remittance_copy['country_name'] == 'Latin America & Caribbean (excluding high income)') |
                             (remittance_copy['country_name'] == 'Late-demographic dividend') |
                             (remittance_copy['country_name'] == 'Africa Eastern and Southern') |
                             (remittance_copy['country_name'] == 'Turkiye') |
                             (remittance_copy['country_name'] == 'IDA only') |
                             (remittance_copy['country_name'] == 'Africa Western and Central') |
                             (remittance_copy['country_name'] == 'Other small states') |
                             (remittance_copy['country_name'] == 'Pre-demographic dividend') |
                             (remittance_copy['country_name'] == 'Sao Tome and Principe') |
                             (remittance_copy['country_name'] == 'Sub-Saharan Africa') |
                             (remittance_copy['country_name'] == 'Sub-Saharan Africa (IDA & IBRD countries)') |
                             (remittance_copy['country_name'] == 'Curaçao') |
                             (remittance_copy['country_name'] == 'Arab World') |
                            (remittance_copy['country_name'] == 'Middle East & North Africa (IDA & IBRD countries)') |
                            (remittance_copy['country_name'] == 'Post-demographic dividend') |
                            (remittance_copy['country_name'] == 'Middle East & North Africa (excluding high income)') |
                            (remittance_copy['country_name'] == 'Early-demographic dividend', 'Heavily indebted poor countries (HIPC)') |
                             (remittance_copy['country_name'] == 'Not classified') |
                             (remittance_copy['country_name'] == 'IDA blend') |
                             (remittance_copy['country_name'] == 'Upper middle income') |
                             (remittance_copy['country_name'] == 'Sub-Saharan Africa (excluding high income)') |
                             (remittance_copy['country_name'] == 'Low & middle income') |
                             (remittance_copy['country_name'] == 'Euro area') |
                             (remittance_copy['country_name'] == 'Europe & Central Asia (IDA & IBRD countries)') |
                             (remittance_copy['country_name'] == 'World') |
                             (remittance_copy['country_name'] == 'Curacao') |
                             (remittance_copy['country_name'] == 'Pacific island small states') |
                             (remittance_copy['country_name'] == "Cote d'Ivoire") |
                             (remittance_copy['country_name'] == 'IDA & IBRD total') |
                             (remittance_copy['country_name'] == 'Middle East & North Africa') |
                              (remittance_copy['country_name'] == 'São Tomé and Principe') |
                              (remittance_copy['country_name'] == "Côte d'Ivoire") |
                              (remittance_copy['country_name'] == 'South Asia (IDA & IBRD)') |
                              (remittance_copy['country_name'] == 'Central Europe and the Baltics') |
                                 (remittance_copy['country_name'] == 'European Union')].index
remittance_copy.drop(indexNames, inplace=True)
remittance_copy
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1526     def __nonzero__(self):
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_300\1797213330.py in <module>
#       1 # removing the countries so the number of countries in metadata will be thesame  in the remittance data
# ----> 2 indexNames = remittance_copy[(remittance_copy['country_name'] == 'Lower middle income') |
# ...
