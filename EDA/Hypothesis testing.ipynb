# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('remitance_merged_migration.csv')

# %%
df.head()
# Out:
#    Year country_code country_name  gdp new_income_group  new_region  \
# 0  1970          AFG  Afghanistan  0.0       Low income  South Asia
# 1  1971          AFG  Afghanistan  0.0       Low income  South Asia
# 2  1972          AFG  Afghanistan  0.0       Low income  South Asia
# 3  1973          AFG  Afghanistan  0.0       Low income  South Asia
# 4  1974          AFG  Afghanistan  0.0       Low income  South Asia
#
#    population  remittance_growth_rate  remittance_paid  remittance_per_capita  \
# 0    10752971                     0.0              0.0                    0.0
# 1    11015857                     0.0              0.0                    0.0
# 2    11286753                     0.0              0.0                    0.0
# 3    11575305                     0.0              0.0                    0.0
# 4    11869879                     0.0              0.0                    0.0
#
#    remittance_received  remittance_to_gdp_ratio  remittance_volatility  \
# 0                  0.0                      0.0            293485541.0
# 1                  0.0                      0.0            293485541.0
# 2                  0.0                      0.0            293485541.0
# 3                  0.0                      0.0            293485541.0
# 4                  0.0                      0.0            293485541.0
#
#    unemployment_rate  unemployment_rate_change  net_migration
# 0                0.0                       0.0           4458
# 1                0.0                       0.0         -12801
# 2                0.0                       0.0          -4050
# 3                0.0                       0.0          -3030
# 4                0.0                       0.0         -20009

# %%
df.tail()
# Out:
#        Year country_code country_name       gdp     new_income_group  \
# 10171  2018          ZWE     Zimbabwe  4.179939  Lower middle income
# 10172  2019          ZWE     Zimbabwe  6.490458  Lower middle income
# 10173  2020          ZWE     Zimbabwe  8.517271  Lower middle income
# 10174  2021          ZWE     Zimbabwe  6.985948  Lower middle income
# 10175  2022          ZWE     Zimbabwe  9.901347  Lower middle income
#
#                new_region  population  remittance_growth_rate  \
# 10171  Sub-Saharan Africa    15052184              -17.468271
# 10172  Sub-Saharan Africa    15354608               -0.748830
# 10173  Sub-Saharan Africa    15669666               29.288915
# 10174  Sub-Saharan Africa    15993524                8.185447
# 10175  Sub-Saharan Africa    16320537                3.300000
#
#        remittance_paid  remittance_per_capita  remittance_received  \
# 10171      29278892.45              94.850224         1.427703e+09
# 10172      13480565.66              92.285779         1.417012e+09
# 10173      21707094.03             116.916301         1.832039e+09
# 10174             0.00             123.925159         1.982000e+09
# 10175             0.00             125.449671         2.047406e+09
#
#        remittance_to_gdp_ratio  remittance_volatility  unemployment_rate  \
# 10171              341560699.0            888192367.2              6.784
# 10172              218322349.3            888192367.2              7.370
# 10173              215096984.1            888192367.2              7.898
# 10174              283712386.7            888192367.2              8.067
# 10175              206780556.0            888192367.2              7.945
#
#        unemployment_rate_change  net_migration
# 10171                     0.505         -59918
# 10172                     0.586         -59918
# 10173                     0.528         -29955
# 10174                     0.169         -25005
# 10175                    -0.122              0

# %%
df.isnull().sum()
# Out:
# Year                        0
# country_code                0
# country_name                0
# gdp                         0
# new_income_group            0
# new_region                  0
# population                  0
# remittance_growth_rate      0
# remittance_paid             0
# remittance_per_capita       0
# remittance_received         0
# remittance_to_gdp_ratio     0
# remittance_volatility       0
# unemployment_rate           0
# unemployment_rate_change    0
# net_migration               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10176 entries, 0 to 10175
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Year                      10176 non-null  int64
#  1   country_code              10176 non-null  object
#  2   country_name              10176 non-null  object
#  3   gdp                       10176 non-null  float64
#  4   new_income_group          10176 non-null  object
#  5   new_region                10176 non-null  object
#  6   population                10176 non-null  int64
#  7   remittance_growth_rate    10176 non-null  float64
#  8   remittance_paid           10176 non-null  float64
#  9   remittance_per_capita     10176 non-null  float64
#  10  remittance_received       10176 non-null  float64
#  11  remittance_to_gdp_ratio   10176 non-null  float64
#  12  remittance_volatility     10176 non-null  float64
#  13  unemployment_rate         10176 non-null  float64
#  14  unemployment_rate_change  10176 non-null  float64
#  15  net_migration             10176 non-null  int64
# dtypes: float64(9), int64(3), object(4)
# memory usage: 1.2+ MB

# %% [markdown]
# 1. Year (Numerical - Continuous)
# 2. country_code (Categorical - Nominal)
# 3. country_name (Categorical - Nominal)
# 4. gdp (Numerical - Continuous)
# 5. new_income_group (Categorical - Ordinal)
# 6. new_region (Categorical - Nominal)
# 7. population (Numerical - Discrete)
# 8. remittance_growth_rate (Numerical - Continuous)
# 9. remittance_paid (Numerical - Continuous)
# 10. remittance_per_capita (Numerical - Continuous)
# 11. remittance_received (Numerical - Continuous)
# 12. remittance_to_gdp_ratio (Numerical - Continuous)
# 13. remittance_volatility (Numerical - Continuous)
# 14. unemployment_rate (Numerical - Continuous)
# 15. unemployment_rate_change (Numerical - Continuous)

# %%
#large sample size
df.shape
# Out:
# (10176, 16)

# %%
df.describe().T
# Out:
#                             count          mean           std        min  \
# Year                      10176.0  1.996000e+03  1.529781e+01     1970.0
# gdp                       10176.0  2.661323e+00  8.784631e+00        0.0
# population                10176.0  3.004534e+07  1.168006e+08     5814.0
# remittance_growth_rate    10176.0           inf           NaN     -100.0
# remittance_paid           10176.0  8.430714e+08  3.860485e+09        0.0
# remittance_per_capita     10176.0  8.663760e+01  2.243029e+02        0.0
# remittance_received       10176.0  1.125116e+09  4.248909e+09        0.0
# remittance_to_gdp_ratio   10176.0  1.844083e+09  1.048231e+10        0.0
# remittance_volatility     10176.0  1.315537e+09  3.172005e+09        0.0
# unemployment_rate         10176.0  4.437800e+00  5.982877e+00        0.0
# unemployment_rate_change  10176.0 -5.680031e-04  7.924122e-01       -7.3
# net_migration             10176.0  1.470797e+02  1.597650e+05 -2290411.0
#
#                                   25%           50%           75%  \
# Year                          1983.00  1.996000e+03  2.009000e+03
# gdp                              0.00  2.139296e-01  2.214162e+00
# population                 1341673.00  5.781454e+06  1.839501e+07
# remittance_growth_rate           0.00  0.000000e+00  1.088905e+01
# remittance_paid                  0.00  8.844155e+06  1.520000e+08
# remittance_per_capita            0.00  6.156980e+00  7.643219e+01
# remittance_received              0.00  2.345000e+07  5.704182e+08
# remittance_to_gdp_ratio          0.00  2.230003e+07  3.779263e+08
# remittance_volatility     48331084.71  2.983998e+08  1.089087e+09
# unemployment_rate                0.00  2.132000e+00  7.099250e+00
# unemployment_rate_change        -0.02  0.000000e+00  7.000000e-03
# net_migration               -17574.25 -9.420000e+02  7.353000e+03
#
#                                    max
# Year                      2.022000e+03
# gdp                       2.359280e+02
# population                1.417173e+09
# remittance_growth_rate             inf
# remittance_paid           7.915300e+10
# remittance_per_capita     3.800143e+03
# remittance_received       1.110000e+11
# remittance_to_gdp_ratio   2.550000e+11
# remittance_volatility     3.185556e+10
# unemployment_rate         3.880000e+01
# unemployment_rate_change  1.970800e+01
# net_migration             1.866819e+06

# %%
#List all the numerical columns
cols = df.columns
ldf = list(df.columns)
num_cols=[]
for i in cols:
    types = df[i].dtypes
    if types=='float64':
        num_cols.append(i)
    if types=='int64':
        num_cols.append(i)

# %%
num_cols
# Out:
# ['Year',
#  'gdp',
#  'population',
#  'remittance_growth_rate',
#  'remittance_paid',
#  'remittance_per_capita',
#  'remittance_received',
#  'remittance_to_gdp_ratio',
#  'remittance_volatility',
#  'unemployment_rate',
#  'unemployment_rate_change',
#  'net_migration']

# %%
#Remittance growth rate column has float infinity problem so, we will remove it

# %%
num_cols = ['Year','gdp','population','remittance_paid','remittance_per_capita','remittance_received',
 'remittance_to_gdp_ratio','remittance_volatility','unemployment_rate','unemployment_rate_change','net_migration']

# %%
len(num_cols)
# Out:
# 11

# %%
#Plot all numerical columns to check if it is normally distributed
fig,axs = plt.subplots(nrows=6,ncols=2,figsize=(30,25))
axs = axs.flatten()
for i,col in enumerate(num_cols):
    data = df[col]
    sns.distplot(data,ax=axs[i])
plt.show()
# Out:
# <ipython-input-13-cf800f264340>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data,ax=axs[i])
# <ipython-input-13-cf800f264340>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data,ax=axs[i])
# <ipython-input-13-cf800f264340>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data,ax=axs[i])
# <ipython-input-13-cf800f264340>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data,ax=axs[i])
# <ipython-input-13-cf800f264340>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data,ax=axs[i])
# <ipython-input-13-cf800f264340>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data,ax=axs[i])
# <ipython-input-13-cf800f264340>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data,ax=axs[i])
# <ipython-input-13-cf800f264340>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data,ax=axs[i])
# <ipython-input-13-cf800f264340>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data,ax=axs[i])
# <ipython-input-13-cf800f264340>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data,ax=axs[i])
# <ipython-input-13-cf800f264340>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data,ax=axs[i])

# %%
num_cols
# Out:
# ['Year',
#  'gdp',
#  'population',
#  'remittance_paid',
#  'remittance_per_capita',
#  'remittance_received',
#  'remittance_to_gdp_ratio',
#  'remittance_volatility',
#  'unemployment_rate',
#  'unemployment_rate_change',
#  'net_migration']

# %% [markdown]
# Right skewed distribution
# 1. GDP
# 2. Population
# 3. Remittance per capita
# 4. Unemployment rate
# 5. Remittance received
# 6. Remittance paid
# 7. Remittance to GDP ratio

# %% [markdown]
# Non-normal distribution
#
# 1. Remittance volatility

# %% [markdown]
# Normal distribution
#
# 1. Year
# 2. Unemployment rate change
# 3. Net migration

# %%
#Check if outliers exist in each column

#Function to plot boxplots
def show_boxplots(d):
    a = df[d]
    plt.rcParams['figure.figsize']==[12,5]
    plt.figure(figsize=(15,10))
    sns.boxplot(data=a,orient='v')
    plt.title('OUTLIER DISTRIBUTION')
    plt.ylabel("Range",fontweight='bold')
    plt.xlabel(d,fontweight='bold')

# %%
for i in num_cols:
    show_boxplots(i)

# %% [markdown]
# Columns with outliers:
#
# • GDP
#
# • Population
#
# • Remittance Paid
#
# • Remittance per Capita
#
# • Remittance received
#
# • Remittance to GDP ratio
#
# • Remittance volatility
#
# • Unemployment rate
#
# • Unemployment rate change
#
# • Net migration

# %%
corr = df.corr()
plt.figure(figsize=(12,5))
sns.heatmap(corr,annot=True)

# %% [markdown]
# Positively correlated
#
# • Year and Unemployment Rate
#
# • Population and Remittance Volatility
#
# • Population and Remittance to GDP ratio
#
# • Population and Remittance received
#
# • Remittance received and Remittance volatility
#
# • Remittance paid and Remittance to GDP ratio
#
# • Year and Remittance Per Capita
#
# • GDP and Remittance per Capita

# %% [markdown]
# STATISTICAL ANALYSIS

# %%
from scipy.stats import pearsonr

# %% [markdown]
# H1: Countries with higher population are more likely to have high remittance received

# %%
population = df['population']
remitt_received = df['remittance_received']

# %%
corr1 = population.corr(remitt_received,method='pearson')
print("Correlation between Population and Remittance received is: ",corr1)
# Out:
# Correlation between Population and Remittance received is:  0.5037893655148472

# %%
#create a scatter plot
plt.figure(figsize=(12,5))
plt.scatter(population,remitt_received,c='purple')
plt.xlabel('Population')
plt.ylabel('Remittance received')
plt.title("Population vs. Remittance received")
# Out:
# Text(0.5, 1.0, 'Population vs. Remittance received')

# %% [markdown]
# Observation
#
# • As population increases, the remittance received increases to some extent

# %% [markdown]
# H2: Countries with higher population are more likely to have high remittance paid

# %%
population = df['population']
remitt_paid = df['remittance_paid']

# %%
corr2 = population.corr(remitt_paid,method='pearson')
print("Correlation between Population and Remittance paid is: ",corr2)
# Out:
# Correlation between Population and Remittance paid is:  0.18063624999153807

# %%
#create a scatter plot
plt.figure(figsize=(12,5))
plt.scatter(population,remitt_paid,c='orange')
plt.xlabel('Population')
plt.ylabel('Remittance paid')
plt.title("Population vs. Remittance paid")
# Out:
# Text(0.5, 1.0, 'Population vs. Remittance paid')

# %% [markdown]
# Observation
#
# • As population increases, there is no increase in remittance paid

# %% [markdown]
# H3: Countries with higher population are more likely to have high remittance to GDP ratio

# %%
population = df['population']
remitt_gdp= df['remittance_to_gdp_ratio']
corr3 = population.corr(remitt_gdp,method='pearson')
print("Correlation between Population and Remittance to GDP ratio is: ",corr3)
# Out:
# Correlation between Population and Remittance to GDP ratio is:  0.39662446446265953

# %%
#create a scatter plot
plt.figure(figsize=(12,5))
plt.scatter(population,remitt_gdp,c='green')
plt.xlabel('Population')
plt.ylabel('Remittance to GDP ratio')
plt.title("Population vs. Remittance to GDP ratio")
# Out:
# Text(0.5, 1.0, 'Population vs. Remittance to GDP ratio')

# %% [markdown]
# Observation
#
# • As population increases, there is some extent of increase in remittance ot GDP ratio

# %% [markdown]
# H4: Countries with higher remittance received are more likely to have high remittance volatility

# %%
population = df['population']
remitt_vol= df['remittance_volatility']
corr4 = population.corr(remitt_vol,method='pearson')
print("Correlation between Population and Remittance Volatility is: ",corr4)
# Out:
# Correlation between Population and Remittance Volatility is:  0.6814480029588091

# %%
#create a scatter plot
plt.figure(figsize=(12,5))
plt.scatter(population,remitt_vol,c='blue')
plt.xlabel('Population')
plt.ylabel('Remittance Volatility')
plt.title("Population vs. Remittance Volatility")
# Out:
# Text(0.5, 1.0, 'Population vs. Remittance Volatility')

# %% [markdown]
# Observation
#
# • As population increases, there is an increase in remittance volatility

# %% [markdown]
# H5: Countries with high population have high net migration

# %%
population = df['population']
net= df['net_migration']
corr5 = population.corr(net,method='pearson')
print("Correlation between Population and Net migration is: ",corr5)
# Out:
# Correlation between Population and Net migration is:  -0.09132935797704222

# %%
#create a scatter plot
plt.figure(figsize=(12,5))
plt.scatter(population,net,c='red')
plt.xlabel('Population')
plt.ylabel('Net migration')
plt.title("Population vs. Net migration")
# Out:
# Text(0.5, 1.0, 'Population vs. Net migration')

# %% [markdown]
# Observation
#
# • As population increases, net migration is neighter low or high

# %% [markdown]
# H6: Countries high net migration have high gdp

# %%
net = df['net_migration']
gdp= df['gdp']
corr6 = net.corr(gdp,method='pearson')
print("Correlation between net migration and GDP is: ",corr6)
# Out:
# Correlation between net migration and GDP is:  -0.04696879395214345

# %%
#create a scatter plot
plt.figure(figsize=(12,5))
plt.scatter(net,gdp,c='red')
plt.xlabel('net migration')
plt.ylabel('gdp')
plt.title("Net migration vs. GDP ")
# Out:
# Text(0.5, 1.0, 'Net migration vs. GDP ')

# %% [markdown]
# H6: Countries in certain regions are more likely to be considered as high income group

# %%
df['new_income_group'].unique()
# Out:
# array(['Low income', 'Upper middle income', 'Lower middle income',
#        'High income'], dtype=object)

# %%
income_mapping = {'Low income':1, 'Lower middle income':2,'Upper middle income':3,'High income':4}

# %%
df['new_income_group']=df['new_income_group'].map(income_mapping)

# %%
region = df['new_region']
avg_income = df.groupby('new_region')['new_income_group'].mean()
avg_income
# Out:
# new_region
# East Asia & Pacific           2.733333
# Europe & Central Asia         3.557692
# Latin America & Caribbean     3.156250
# Middle East & North Africa    2.800000
# North America                 4.000000
# South Asia                    2.000000
# Sub-Saharan Africa            1.708333
# Name: new_income_group, dtype: float64

# %%
contingency_tab = pd.DataFrame(avg_income,region)

# %%
contingency_tab
# Out:
#                     new_income_group
# new_region
# South Asia                  2.000000
# South Asia                  2.000000
# South Asia                  2.000000
# South Asia                  2.000000
# South Asia                  2.000000
# ...                              ...
# Sub-Saharan Africa          1.708333
# Sub-Saharan Africa          1.708333
# Sub-Saharan Africa          1.708333
# Sub-Saharan Africa          1.708333
# Sub-Saharan Africa          1.708333
#
# [10176 rows x 1 columns]

# %%
from scipy.stats import chi2_contingency
chi2, p_value, _, _ = chi2_contingency(contingency_tab)

# %%
print("Average Income level by region:")
print(avg_income)
print("")

print("Chi-Square Test Results:")
print("Chi-Square:", chi2)
print("p-value:", p_value)
# Out:
# Average Income level by region:
# new_region
# East Asia & Pacific           2.733333
# Europe & Central Asia         3.557692
# Latin America & Caribbean     3.156250
# Middle East & North Africa    2.800000
# North America                 4.000000
# South Asia                    2.000000
# Sub-Saharan Africa            1.708333
# Name: new_income_group, dtype: float64
#
# Chi-Square Test Results:
# Chi-Square: 0.0
# p-value: 1.0

# %%
print("Minimum average income by region:", avg_income.min())
print("Maximum average income by region:", avg_income.max())
# Out:
# Minimum average income by region: 1.7083333333333333
# Maximum average income by region: 4.0

# %% [markdown]
# Observation
#
# • The contingency table shows the distribution of income group across different region.
#
# •

# %% [markdown]
# Observation
#
# •

# %% [markdown]
# One way ANOVA

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
model = ols('gdp ~ new_income_group',data=df).fit()

# %%
aovRes = sm.stats.anova_lm(model,typ=2)
aovRes
# Out:
#                          sum_sq       df           F        PR(>F)
# new_income_group   10217.994853      1.0  134.141958  7.936188e-31
# Residual          774984.061103  10174.0         NaN           NaN

# %% [markdown]
# Statistical Tests to use:
#     1. Z-test
#     2. ANOVA test
#     3. Chi-squared test
#     4. Correlation test
#
# Hypothesis testing factors:
#     1. Distribution of sample
#     2. Sample size
#     3. Variance is known
#     4. Type of data that you have
#
# Steps involved in hypothesis testing:
#     1. Formulate your hypotheses
#     2. Choosing a level of significance
#     3. Identifying a statistical test
#     4. Calculating the test statistic
#     5. Calculating the p-value and comparing it with the level of signficance
#     6. Concluding - rejecting or not rejecting your null hypothesis
